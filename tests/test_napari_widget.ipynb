# %%
import matplotlib.pyplot as plt
import numpy as np
import flimtools
import tifffile

# %%
#img=flimtools.readBin('TileScan_003_s1_z1_seq1.bin')
img=tifffile.imread('TileScan_003_s1_z1_seq1_crop_8bit.tif')

# %%
gimg,simg,sumimg=flimtools.calcGSimg(img,45,1)

# %%
gshist,gbins,sbins,gthresh,sthresh,xthreshcoords,ythreshcoords=flimtools.getGSHist(gimg,simg,sumimg,smsigma=3,thresh=3)

# %%
#need this magic to get interactivity
# %matplotlib notebook
fig=flimtools.showHist(gshist,gbins,sbins,points=np.array([[0.28,0.42],[0.21,0.15],[0.74,0.26]]),ptsizes=[0.1,0.1,0.1])
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
#have to wait to import napari tools until here for background color issues
import napariflim
# Out:
# napari.manifest -> 'napari-molecule-reader' could not be imported: Could not find file 'napari.yml' in module 'napari_molecule_reader'

# %%
viewer=napariflim.startNapariWidget(gimg,simg,sumimg,points=[[0.65,0.4],[0.27,0.2]])
# Out:
# /Users/jru/opt/miniconda3/envs/naparienv/lib/python3.8/site-packages/napari_tools_menu/__init__.py:168: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# [0.23000000000000004, 0.33000000000000007, 0.37, 0.47]
# [0.7, 0.7999999999999999, 0.2, 0.30000000000000004]
